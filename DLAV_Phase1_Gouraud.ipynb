# %% [markdown]
# # DLAV Project - Phase 1
#
# In this notebook we will train a very simple planner on data coming from a driving simulator. You are given a dash cam image of the current state of the driving vehicle, and the past positions of this vehicle, and you are asked to plan its future route.
#
# This notebook will take you through steps on building this planner to solve the task. The full skeleton of the code together with some very simple implementations of each module are provided for your comfort. So all the cells below will run without you needing to change anything, but the performance won't be very good. You are asked to re-implement and play with most of the modules yourself to be able to have better performance.
#
# P.S. to enable fast compute, you should use GPUs in google colab. The code works without GPUs, but it'll be much faster to use GPUs, specially if your model gets bigger and bigger! You can utilize Colab's GPUs by selecting "Change runtime type" in the Runtime menu on top of this page. There you can select "T4 GPU". This would restart your runtime, so you'll need to re-run everything from the top.

# %% [markdown]
# The first step is to prepare the data. The code below will download the data from google drive and extract it here for your code to use. Whenever your session gets restarted, remember to re-run this cell to re-download the data.

# %%
# Install gdown to handle Google Drive file download
# !pip install -q gdown

import gdown
import zipfile

download_url = f"https://drive.google.com/uc?id=1YkGwaxBKNiYL2nq--cB6WMmYGzRmRKVr"
output_zip = "dlav_train.zip"
gdown.download(download_url, output_zip, quiet=False)  # Downloads the file to your drive
with zipfile.ZipFile(output_zip, 'r') as zip_ref:  # Extracts the downloaded zip file
    zip_ref.extractall(".")

download_url = "https://drive.google.com/uc?id=1wtmT_vH9mMUNOwrNOMFP6WFw6e8rbOdu"
output_zip = "dlav_val.zip"
gdown.download(download_url, output_zip, quiet=False)
with zipfile.ZipFile(output_zip, 'r') as zip_ref:
    zip_ref.extractall(".")

download_url = "https://drive.google.com/uc?id=1G9xGE7s-Ikvvc2-LZTUyuzhWAlNdLTLV"
output_zip = "dlav_test_public.zip"
gdown.download(download_url, output_zip, quiet=False)
with zipfile.ZipFile(output_zip, 'r') as zip_ref:
    zip_ref.extractall(".")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1YkGwaxBKNiYL2nq--cB6WMmYGzRmRKVr
# From (redirected): https://drive.google.com/uc?id=1YkGwaxBKNiYL2nq--cB6WMmYGzRmRKVr&confirm=t&uuid=7eccc297-8ff9-4547-ba64-738911f6bc06
# To: /content/dlav_train.zip
# 100%|██████████| 439M/439M [00:10<00:00, 40.2MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1wtmT_vH9mMUNOwrNOMFP6WFw6e8rbOdu
# From (redirected): https://drive.google.com/uc?id=1wtmT_vH9mMUNOwrNOMFP6WFw6e8rbOdu&confirm=t&uuid=b2c4453a-5bab-402a-a427-e5ee325a21c0
# To: /content/dlav_val.zip
# 100%|██████████| 87.8M/87.8M [00:00<00:00, 102MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1G9xGE7s-Ikvvc2-LZTUyuzhWAlNdLTLV
# From (redirected): https://drive.google.com/uc?id=1G9xGE7s-Ikvvc2-LZTUyuzhWAlNdLTLV&confirm=t&uuid=ab6b88f7-eb94-47a3-ac92-144b3d73af50
# To: /content/dlav_test_public.zip
# 100%|██████████| 86.6M/86.6M [00:01<00:00, 75.2MB/s]

# %% [markdown]
# Now lets load the data and visualize the first few examples to see what we are dealing with!

# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
import random

k = 4
# load the data
data = []
for i in random.choices(np.arange(1000), k=k):
    with open(f"train/{i}.pkl", "rb") as f:
        data.append(pickle.load(f))

# plot the camera view of current step for the k examples
fig, axis = plt.subplots(1, k, figsize=(4*k, 4))
for i in range(k):
    axis[i].imshow(data[i]["camera"])
    axis[i].axis("off")
plt.show()

# plot the past and future trajectory of the vehicle
fig, axis = plt.subplots(1, k, figsize=(4*k, 4))
for i in range(k):
    axis[i].plot(data[i]["sdc_history_feature"][:, 0], data[i]["sdc_history_feature"][:, 1], "o-", color="gold", label="Past")
    axis[i].plot(data[i]["sdc_future_feature"][:, 0], data[i]["sdc_future_feature"][:, 1], "o-", color="green", label="Future")
    axis[i].legend()
    axis[i].axis("equal")
plt.show()

# %% [markdown]
# Now its time to make our hands dirty!
#
# In the following cells we will define the classes we need to do a proper training in pytorch.
#
# 1. We will start with defining a Dataset class which loads the data and does some basic preprocessing. You can further process this data as you see fit.
# 2. We then define the logger which receives training metrics and logs and prints/visualizes them. Having a good logger means a lot when dealing with neural network training! The logger implemented here is very simple and we strongly suggest you try other ways of visualizing your losses and metrics. Be creative ;)
# 3. We then proceed with defining the core part of the pipeline, the model. You are going to mainly implement the model yourself, but we have provided a very simple model so that the code runs as is so that you can see how the whole framework runs all in all.
# 4. Finally, we define the training funciton which contains the training loop, and we call it to see the magic! You'll need to also do a lot of changes here, from the batch size and learning rate, to adding augmentation schemes and schedulers, etc.

# %%
import torch
from torch.utils.data import Dataset
import pickle
from torchvision import transforms

class DrivingDataset(Dataset):
    def __init__(self, file_list, test=False):
        self.samples = file_list
        self.test = test
        self.transform = transforms.Compose([transforms.ToPILImage(),transforms.ColorJitter(brightness=0.3,contrast=0.3,saturation=0.3),transforms.RandomAffine(degrees=5, translate=(0.02, 0.02), scale=(0.95, 1.05)),transforms.ToTensor()])

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        # Load pickle file
        with open(self.samples[idx], 'rb') as f:
            data = pickle.load(f)

        # Convert numpy arrays to tensors
        camera = self.transform(data['camera'])
        history = torch.FloatTensor(data['sdc_history_feature'])
        if not self.test:
          future = torch.FloatTensor(data['sdc_future_feature'])
          return {
            'camera': camera,
            'history': history,
            'future': future
          }
        else:
          return {
            'camera': camera,
            'history': history
          }

# %%
import math
import math
import torch

class Logger:
    def __init__(self):
        self.logs = []

    def log(self, step=None, phase="train", **metrics):
        # Log only every 10 steps
        if step is not None and step % 10 != 0:
            return

        # Format and print
        prefix = f"[{phase.upper()} Step {step}] " if step is not None else f"[{phase.upper()}] "
        metric_str = " | ".join(f"{k}: {v:.4f}" if isinstance(v, float) else f"{k}: {v}" for k, v in metrics.items())
        self.logs.append((step, phase, metrics))
        print(prefix + metric_str)

    def compute_metrics(self, pred, gt):
        """
        pred, gt: torch tensors of shape (B, 60, 3) [x, y, heading]
        Returns: dict of computed metrics
        """
        ade = torch.norm(pred[..., :2] - gt[..., :2], dim=-1).mean().item()
        fde = torch.norm(pred[:, -1, :2] - gt[:, -1, :2], dim=-1).mean().item()

        # Heading error at final step
        heading_error = torch.abs(pred[:, -1, 2] - gt[:, -1, 2])
        heading_error = torch.remainder(heading_error + math.pi, 2 * math.pi) - math.pi
        heading_error = heading_error.abs().mean().item()

        # Miss rate @ 2 meters
        miss_dist = torch.norm(pred[:, -1, :2] - gt[:, -1, :2], dim=-1)
        miss_rate = (miss_dist > 2.0).float().mean().item()

        return {
            "ADE": ade,
            "FDE": fde,
            "HeadingErr(rad)": heading_error,
            "MissRate@2m": miss_rate
        }

# %%
import torch
import torch.nn as nn
import torchvision.models as models
class DrivingPlanner(nn.Module):
    def __init__(self):
        super().__init__()

        base = models.resnet18(pretrained=True)
        self.image_encoder = nn.Sequential(
            *list(base.children())[:-2],
            nn.AdaptiveAvgPool2d((1, 1)),
            nn.Flatten()
        )

        self.traj_encoder = nn.GRU(input_size=3, hidden_size=64, batch_first=True)

        self.fusion = nn.Sequential(
            nn.Linear(512 + 64, 256),
            nn.ReLU(),
            nn.LayerNorm(256),
            nn.Dropout(0.1)
        )


        self.decoder = nn.Sequential(
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Linear(256, 180),
        )

    def forward(self, camera, history):
        B = camera.size(0)

        visual_feat = self.image_encoder(camera)
        _, hidden = self.traj_encoder(history)
        traj_feat = hidden.squeeze(0)
        fused = self.fusion(torch.cat([visual_feat, traj_feat], dim=1))

        future = self.decoder(fused).view(B, 60, 3)
        return future

# %%
def trajectory_smoothness_loss(pred):
    """
    pred: [B, 60, 2 or 3] → predicted trajectory
    Returns a scalar loss: mean L2 norm of second derivatives (acceleration)
    """
    pos = pred[..., :2]
    vel = pos[:, 1:] - pos[:, :-1]
    acc = vel[:, 1:] - vel[:, :-1]
    return acc.pow(2).mean()

from torch.optim import SGD

def train(model, train_loader, val_loader, optimizer, logger, num_epochs=50):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = model.to(device)
    optimizer=SGD(model.parameters(),lr=1e-3,momentum=0.9,weight_decay=1e-4)
    criterion = nn.MSELoss()

    for epoch in range(num_epochs):
        # Training
        model.train()
        train_loss = 0
        for idx, batch in enumerate(train_loader):
            camera = batch['camera'].to(device)
            history = batch['history'].to(device)
            future = batch['future'].to(device)

            optimizer.zero_grad()
            pred_future = model(camera, history)
            loss_pred = criterion(pred_future[..., :2], future[..., :2])
            loss_smooth = trajectory_smoothness_loss(pred_future)
            loss = loss_pred + 0.1 * loss_smooth
            loss.backward()
            optimizer.step()
            metrics=logger.compute_metrics(pred_future, future)
            if idx % 10 == 0:
                logger.log(step=epoch * len(train_loader) + idx,phase='train',**metrics)
            train_loss += loss.item()

        # Validation
        model.eval()
        val_loss, ade_all, fde_all = 0, [], []
        with torch.no_grad():
            for batch in val_loader:
                camera = batch['camera'].to(device)
                history = batch['history'].to(device)
                future = batch['future'].to(device)

                pred_future = model(camera, history)
                loss = criterion(pred_future, future)
                ADE = torch.norm(pred_future[:, :, :2] - future[:, :, :2], p=2, dim=-1).mean()
                FDE = torch.norm(pred_future[:, -1, :2] - future[:, -1, :2], p=2, dim=-1).mean()
                ade_all.append(ADE.item())
                fde_all.append(FDE.item())
                val_loss += loss.item()

        print(f'Epoch {epoch+1}/{num_epochs} | Train Loss: {train_loss/len(train_loader):.4f} | Val Loss: {val_loss/len(val_loader):.4f} | ADE: {np.mean(ade_all):.4f} | FDE: {np.mean(fde_all):.4f}')

# %%
import torch.optim as optim
from torch.utils.data import DataLoader
import os

train_data_dir = "train"
val_data_dir = "val"

train_files = [os.path.join(train_data_dir, f) for f in os.listdir(train_data_dir) if f.endswith('.pkl')]
val_files = [os.path.join(val_data_dir, f) for f in os.listdir(val_data_dir) if f.endswith('.pkl')]

train_dataset = DrivingDataset(train_files)
val_dataset = DrivingDataset(val_files)

train_loader = DataLoader(train_dataset, batch_size=32, num_workers=2, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, num_workers=2)

model = DrivingPlanner()

optimizer = optim.Adam(model.parameters(), lr=1e-3)

logger = Logger()

train(model, train_loader, val_loader, optimizer, logger, num_epochs=50)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# [TRAIN Step 0] ADE: 12.4578 | FDE: 25.2557 | HeadingErr(rad): 0.2223 | MissRate@2m: 0.7188
# [TRAIN Step 10] ADE: 8.8221 | FDE: 17.6041 | HeadingErr(rad): 0.4808 | MissRate@2m: 0.9062
# [TRAIN Step 20] ADE: 11.5287 | FDE: 22.7827 | HeadingErr(rad): 1.6963 | MissRate@2m: 0.9688
# [TRAIN Step 30] ADE: 9.8532 | FDE: 19.1678 | HeadingErr(rad): 1.2938 | MissRate@2m: 1.0000
# [TRAIN Step 40] ADE: 8.5319 | FDE: 17.7514 | HeadingErr(rad): 1.3704 | MissRate@2m: 1.0000
# [TRAIN Step 50] ADE: 8.3279 | FDE: 16.8829 | HeadingErr(rad): 1.4146 | MissRate@2m: 0.9375
# [TRAIN Step 60] ADE: 7.7553 | FDE: 15.4071 | HeadingErr(rad): 1.2357 | MissRate@2m: 0.9062
# [TRAIN Step 70] ADE: 6.5896 | FDE: 13.4731 | HeadingErr(rad): 1.2951 | MissRate@2m: 0.9688
# [TRAIN Step 80] ADE: 7.6962 | FDE: 16.0023 | HeadingErr(rad): 1.2622 | MissRate@2m: 0.9688
# [TRAIN Step 90] ADE: 7.4829 | FDE: 15.1730 | HeadingErr(rad): 1.0836 | MissRate@2m: 0.9375
# [TRAIN Step 100] ADE: 7.0911 | FDE: 15.2760 | HeadingErr(rad): 1.1946 | MissRate@2m: 0.8438
# [TRAIN Step 110] ADE: 5.7846 | FDE: 11.9644 | HeadingErr(rad): 1.0899 | MissRate@2m: 0.8750
# [TRAIN Step 120] ADE: 6.8597 | FDE: 13.7794 | HeadingErr(rad): 1.0298 | MissRate@2m: 0.9688
# [TRAIN Step 130] ADE: 4.5703 | FDE: 10.6356 | HeadingErr(rad): 1.4612 | MissRate@2m: 0.9375
# [TRAIN Step 140] ADE: 4.1976 | FDE: 8.6606 | HeadingErr(rad): 0.9450 | MissRate@2m: 0.9062
# [TRAIN Step 150] ADE: 3.8460 | FDE: 8.4185 | HeadingErr(rad): 1.0252 | MissRate@2m: 0.8438
# Epoch 1/50 | Train Loss: 70.2771 | Val Loss: 19.1660 | ADE: 4.9584 | FDE: 11.2405
# Epoch 2/50 | Train Loss: 16.5323 | Val Loss: 11.0468 | ADE: 3.6477 | FDE: 8.4775
# Epoch 3/50 | Train Loss: 13.3946 | Val Loss: 8.3421 | ADE: 2.9645 | FDE: 7.6155
# Epoch 4/50 | Train Loss: 12.6288 | Val Loss: 9.9403 | ADE: 3.3490 | FDE: 8.0963
# Epoch 5/50 | Train Loss: 11.5137 | Val Loss: 7.7451 | ADE: 2.7625 | FDE: 7.1104
# Epoch 6/50 | Train Loss: 10.0599 | Val Loss: 7.3087 | ADE: 2.7145 | FDE: 6.9189
# Epoch 7/50 | Train Loss: 9.7221 | Val Loss: 7.3885 | ADE: 2.8188 | FDE: 7.0100
# Epoch 8/50 | Train Loss: 8.9970 | Val Loss: 6.7973 | ADE: 2.5326 | FDE: 6.5601
# Epoch 9/50 | Train Loss: 8.8470 | Val Loss: 7.7904 | ADE: 2.6628 | FDE: 6.8092
# Epoch 10/50 | Train Loss: 8.4624 | Val Loss: 7.9237 | ADE: 2.9055 | FDE: 7.1906
# [TRAIN Step 1570] ADE: 2.5195 | FDE: 6.4766 | HeadingErr(rad): 1.1445 | MissRate@2m: 0.8125
# [TRAIN Step 1580] ADE: 2.3566 | FDE: 5.5970 | HeadingErr(rad): 1.2596 | MissRate@2m: 0.5938
# [TRAIN Step 1590] ADE: 2.2548 | FDE: 5.3667 | HeadingErr(rad): 1.3101 | MissRate@2m: 0.7500
# [TRAIN Step 1600] ADE: 2.4823 | FDE: 5.3906 | HeadingErr(rad): 1.1984 | MissRate@2m: 0.8438
# [TRAIN Step 1610] ADE: 2.1363 | FDE: 5.3388 | HeadingErr(rad): 0.8085 | MissRate@2m: 0.8125
# [TRAIN Step 1620] ADE: 2.0583 | FDE: 4.6374 | HeadingErr(rad): 1.1138 | MissRate@2m: 0.5625
# [TRAIN Step 1630] ADE: 2.4731 | FDE: 5.9260 | HeadingErr(rad): 1.0289 | MissRate@2m: 0.7500
# [TRAIN Step 1640] ADE: 2.5516 | FDE: 6.5480 | HeadingErr(rad): 1.4757 | MissRate@2m: 0.7812
# [TRAIN Step 1650] ADE: 2.5798 | FDE: 6.5342 | HeadingErr(rad): 1.0844 | MissRate@2m: 0.7812
# [TRAIN Step 1660] ADE: 2.6328 | FDE: 6.6404 | HeadingErr(rad): 0.9163 | MissRate@2m: 0.6562
# [TRAIN Step 1670] ADE: 2.7000 | FDE: 6.7460 | HeadingErr(rad): 1.2156 | MissRate@2m: 0.8438
# [TRAIN Step 1680] ADE: 2.0296 | FDE: 5.6750 | HeadingErr(rad): 1.0690 | MissRate@2m: 0.6875
# [TRAIN Step 1690] ADE: 2.5507 | FDE: 6.6509 | HeadingErr(rad): 1.3543 | MissRate@2m: 0.7812
# [TRAIN Step 1700] ADE: 2.2322 | FDE: 5.5789 | HeadingErr(rad): 1.0787 | MissRate@2m: 0.7188
# [TRAIN Step 1710] ADE: 2.1478 | FDE: 5.8218 | HeadingErr(rad): 1.1684 | MissRate@2m: 0.7500
# [TRAIN Step 1720] ADE: 3.0836 | FDE: 7.5319 | HeadingErr(rad): 1.0390 | MissRate@2m: 0.8125
# Epoch 11/50 | Train Loss: 8.0729 | Val Loss: 7.0202 | ADE: 2.6104 | FDE: 6.7187
# Epoch 12/50 | Train Loss: 7.9185 | Val Loss: 8.1060 | ADE: 2.9326 | FDE: 6.9705
# Epoch 13/50 | Train Loss: 7.3546 | Val Loss: 11.6602 | ADE: 3.9357 | FDE: 8.5756
# Epoch 14/50 | Train Loss: 7.0351 | Val Loss: 6.1518 | ADE: 2.4707 | FDE: 6.1112
# Epoch 15/50 | Train Loss: 6.2692 | Val Loss: 6.1733 | ADE: 2.3649 | FDE: 6.0205
# Epoch 16/50 | Train Loss: 5.8854 | Val Loss: 5.6530 | ADE: 2.4056 | FDE: 5.9651
# Epoch 17/50 | Train Loss: 5.2599 | Val Loss: 7.1000 | ADE: 2.6708 | FDE: 6.6151
# Epoch 18/50 | Train Loss: 5.0613 | Val Loss: 5.6951 | ADE: 2.2933 | FDE: 5.8502
# Epoch 19/50 | Train Loss: 4.7495 | Val Loss: 5.7098 | ADE: 2.4237 | FDE: 5.7494
# Epoch 20/50 | Train Loss: 4.2598 | Val Loss: 5.5013 | ADE: 2.3560 | FDE: 5.7489
# [TRAIN Step 3140] ADE: 1.9473 | FDE: 4.7446 | HeadingErr(rad): 1.4188 | MissRate@2m: 0.6250
# [TRAIN Step 3150] ADE: 1.5838 | FDE: 3.6741 | HeadingErr(rad): 1.2310 | MissRate@2m: 0.7188
# [TRAIN Step 3160] ADE: 1.4087 | FDE: 3.6329 | HeadingErr(rad): 1.5813 | MissRate@2m: 0.6562
# [TRAIN Step 3170] ADE: 1.5045 | FDE: 3.6799 | HeadingErr(rad): 1.3981 | MissRate@2m: 0.6562
# [TRAIN Step 3180] ADE: 1.4408 | FDE: 3.4780 | HeadingErr(rad): 1.0378 | MissRate@2m: 0.5625
# [TRAIN Step 3190] ADE: 2.1236 | FDE: 4.8680 | HeadingErr(rad): 1.2871 | MissRate@2m: 0.7188
# [TRAIN Step 3200] ADE: 1.5003 | FDE: 3.6458 | HeadingErr(rad): 1.3017 | MissRate@2m: 0.6250
# [TRAIN Step 3210] ADE: 1.7006 | FDE: 4.1912 | HeadingErr(rad): 1.2817 | MissRate@2m: 0.6250
# [TRAIN Step 3220] ADE: 1.8570 | FDE: 4.4899 | HeadingErr(rad): 1.6550 | MissRate@2m: 0.7188
# [TRAIN Step 3230] ADE: 1.8970 | FDE: 3.9637 | HeadingErr(rad): 1.2245 | MissRate@2m: 0.5938
# [TRAIN Step 3240] ADE: 2.3127 | FDE: 5.6398 | HeadingErr(rad): 1.6230 | MissRate@2m: 0.8438
# [TRAIN Step 3250] ADE: 1.7177 | FDE: 4.6467 | HeadingErr(rad): 1.1732 | MissRate@2m: 0.7188
# [TRAIN Step 3260] ADE: 2.3103 | FDE: 5.1392 | HeadingErr(rad): 1.4433 | MissRate@2m: 0.7812
# [TRAIN Step 3270] ADE: 1.5312 | FDE: 3.8531 | HeadingErr(rad): 0.8106 | MissRate@2m: 0.5625
# [TRAIN Step 3280] ADE: 1.5755 | FDE: 4.0389 | HeadingErr(rad): 1.4602 | MissRate@2m: 0.8438
# [TRAIN Step 3290] ADE: 1.5608 | FDE: 4.0140 | HeadingErr(rad): 1.3221 | MissRate@2m: 0.6875
# Epoch 21/50 | Train Loss: 3.9335 | Val Loss: 5.4694 | ADE: 2.2413 | FDE: 5.6646
# Epoch 22/50 | Train Loss: 3.7536 | Val Loss: 5.4212 | ADE: 2.2360 | FDE: 5.5842
# Epoch 23/50 | Train Loss: 3.5279 | Val Loss: 5.6510 | ADE: 2.2696 | FDE: 5.6865
# Epoch 24/50 | Train Loss: 3.3552 | Val Loss: 5.7328 | ADE: 2.2510 | FDE: 5.5432
# Epoch 25/50 | Train Loss: 3.1687 | Val Loss: 4.9143 | ADE: 2.0862 | FDE: 5.3983
# Epoch 26/50 | Train Loss: 2.7854 | Val Loss: 5.0112 | ADE: 2.1185 | FDE: 5.4413
# Epoch 27/50 | Train Loss: 2.7901 | Val Loss: 6.0724 | ADE: 2.3277 | FDE: 5.9904
# Epoch 28/50 | Train Loss: 2.5672 | Val Loss: 5.1069 | ADE: 2.0880 | FDE: 5.3252
# Epoch 29/50 | Train Loss: 2.2176 | Val Loss: 4.8972 | ADE: 2.0501 | FDE: 5.2732
# Epoch 30/50 | Train Loss: 2.1761 | Val Loss: 5.1048 | ADE: 2.0533 | FDE: 5.3511
# [TRAIN Step 4710] ADE: 0.9936 | FDE: 2.5323 | HeadingErr(rad): 1.1544 | MissRate@2m: 0.5938
# [TRAIN Step 4720] ADE: 1.3655 | FDE: 3.1871 | HeadingErr(rad): 1.4292 | MissRate@2m: 0.6250
# [TRAIN Step 4730] ADE: 1.7040 | FDE: 4.0345 | HeadingErr(rad): 1.0227 | MissRate@2m: 0.8125
# [TRAIN Step 4740] ADE: 1.3707 | FDE: 3.3012 | HeadingErr(rad): 1.4238 | MissRate@2m: 0.5938
# [TRAIN Step 4750] ADE: 1.6239 | FDE: 3.7186 | HeadingErr(rad): 1.5271 | MissRate@2m: 0.5938
# [TRAIN Step 4760] ADE: 1.4032 | FDE: 3.4940 | HeadingErr(rad): 1.2103 | MissRate@2m: 0.6875
# [TRAIN Step 4770] ADE: 1.5886 | FDE: 3.8717 | HeadingErr(rad): 1.4323 | MissRate@2m: 0.6562
# [TRAIN Step 4780] ADE: 1.3183 | FDE: 3.0326 | HeadingErr(rad): 1.3414 | MissRate@2m: 0.6250
# [TRAIN Step 4790] ADE: 1.1057 | FDE: 2.8227 | HeadingErr(rad): 1.4345 | MissRate@2m: 0.5625
# [TRAIN Step 4800] ADE: 1.3216 | FDE: 3.4852 | HeadingErr(rad): 1.4603 | MissRate@2m: 0.6875
# [TRAIN Step 4810] ADE: 1.3109 | FDE: 3.0302 | HeadingErr(rad): 1.5539 | MissRate@2m: 0.6250
# [TRAIN Step 4820] ADE: 1.2347 | FDE: 2.6966 | HeadingErr(rad): 1.2840 | MissRate@2m: 0.5938
# [TRAIN Step 4830] ADE: 1.0533 | FDE: 2.5518 | HeadingErr(rad): 1.3765 | MissRate@2m: 0.4688
# [TRAIN Step 4840] ADE: 1.2971 | FDE: 2.9953 | HeadingErr(rad): 1.4568 | MissRate@2m: 0.5625
# [TRAIN Step 4850] ADE: 1.1754 | FDE: 3.1871 | HeadingErr(rad): 1.2202 | MissRate@2m: 0.7188
# [TRAIN Step 4860] ADE: 1.0937 | FDE: 2.3366 | HeadingErr(rad): 1.5324 | MissRate@2m: 0.5000
# Epoch 31/50 | Train Loss: 1.9499 | Val Loss: 4.9064 | ADE: 2.0055 | FDE: 5.1965
# Epoch 32/50 | Train Loss: 1.8901 | Val Loss: 5.0122 | ADE: 2.0566 | FDE: 5.2788
# Epoch 33/50 | Train Loss: 1.8056 | Val Loss: 5.0554 | ADE: 2.1103 | FDE: 5.5361
# Epoch 34/50 | Train Loss: 1.6712 | Val Loss: 4.9620 | ADE: 2.0165 | FDE: 5.2538
# Epoch 35/50 | Train Loss: 1.6038 | Val Loss: 4.8133 | ADE: 2.0107 | FDE: 5.2125
# Epoch 36/50 | Train Loss: 1.6390 | Val Loss: 5.1011 | ADE: 2.1116 | FDE: 5.4663
# Epoch 37/50 | Train Loss: 1.5838 | Val Loss: 4.8033 | ADE: 2.0205 | FDE: 5.2567
# Epoch 38/50 | Train Loss: 1.5490 | Val Loss: 4.5587 | ADE: 1.9472 | FDE: 5.1543
# Epoch 39/50 | Train Loss: 1.4662 | Val Loss: 5.0183 | ADE: 2.0400 | FDE: 5.3151
# Epoch 40/50 | Train Loss: 1.4845 | Val Loss: 4.8683 | ADE: 1.9768 | FDE: 5.2180
# [TRAIN Step 6280] ADE: 0.8016 | FDE: 1.8958 | HeadingErr(rad): 1.2701 | MissRate@2m: 0.3750
# [TRAIN Step 6290] ADE: 1.2619 | FDE: 2.9473 | HeadingErr(rad): 1.6128 | MissRate@2m: 0.5625
# [TRAIN Step 6300] ADE: 1.0040 | FDE: 2.3464 | HeadingErr(rad): 0.9999 | MissRate@2m: 0.4688
# [TRAIN Step 6310] ADE: 1.4599 | FDE: 3.1716 | HeadingErr(rad): 1.7142 | MissRate@2m: 0.6250
# [TRAIN Step 6320] ADE: 0.9525 | FDE: 2.0915 | HeadingErr(rad): 0.8677 | MissRate@2m: 0.3750
# [TRAIN Step 6330] ADE: 1.2277 | FDE: 3.0351 | HeadingErr(rad): 1.4270 | MissRate@2m: 0.5625
# [TRAIN Step 6340] ADE: 1.3834 | FDE: 2.8268 | HeadingErr(rad): 1.3313 | MissRate@2m: 0.5938
# [TRAIN Step 6350] ADE: 1.1008 | FDE: 2.6748 | HeadingErr(rad): 1.3182 | MissRate@2m: 0.4375
# [TRAIN Step 6360] ADE: 1.2891 | FDE: 2.8679 | HeadingErr(rad): 1.2800 | MissRate@2m: 0.6250
# [TRAIN Step 6370] ADE: 0.9626 | FDE: 2.3799 | HeadingErr(rad): 0.8896 | MissRate@2m: 0.5625
# [TRAIN Step 6380] ADE: 1.2049 | FDE: 2.7525 | HeadingErr(rad): 1.4254 | MissRate@2m: 0.6250
# [TRAIN Step 6390] ADE: 1.3113 | FDE: 3.4704 | HeadingErr(rad): 1.5010 | MissRate@2m: 0.7188
# [TRAIN Step 6400] ADE: 0.9028 | FDE: 2.2954 | HeadingErr(rad): 1.0365 | MissRate@2m: 0.3438
# [TRAIN Step 6410] ADE: 1.1595 | FDE: 2.5597 | HeadingErr(rad): 1.3601 | MissRate@2m: 0.5938
# [TRAIN Step 6420] ADE: 1.4545 | FDE: 3.3735 | HeadingErr(rad): 1.2710 | MissRate@2m: 0.6250
# [TRAIN Step 6430] ADE: 0.9942 | FDE: 2.0229 | HeadingErr(rad): 1.3497 | MissRate@2m: 0.4062
# Epoch 41/50 | Train Loss: 1.3930 | Val Loss: 5.0177 | ADE: 2.0246 | FDE: 5.3104
# Epoch 42/50 | Train Loss: 1.2844 | Val Loss: 4.8560 | ADE: 1.9256 | FDE: 5.0137
# Epoch 43/50 | Train Loss: 1.2681 | Val Loss: 4.5909 | ADE: 1.8970 | FDE: 4.9504
# Epoch 44/50 | Train Loss: 1.1784 | Val Loss: 4.7118 | ADE: 1.9610 | FDE: 5.1815
# Epoch 45/50 | Train Loss: 1.1317 | Val Loss: 4.6575 | ADE: 1.9836 | FDE: 5.0742
# Epoch 46/50 | Train Loss: 1.2417 | Val Loss: 4.6219 | ADE: 1.9630 | FDE: 5.0993
# Epoch 47/50 | Train Loss: 1.1601 | Val Loss: 4.5688 | ADE: 1.9021 | FDE: 4.9707
# Epoch 48/50 | Train Loss: 1.1391 | Val Loss: 4.5151 | ADE: 1.8661 | FDE: 4.9403
# Epoch 49/50 | Train Loss: 1.1402 | Val Loss: 4.5942 | ADE: 1.8995 | FDE: 4.9681
# Epoch 50/50 | Train Loss: 1.0750 | Val Loss: 4.5893 | ADE: 1.8794 | FDE: 4.9615

# %% [markdown]
# By running the code above, you have trained your first model!
# What do you observe in terms of train and val losses? What is this phenomenon called? (Explain in a few lines below)
#
#
#
#
# This model is very simple and does not necessarilly yield the optimal performance. You are asked to implement your own neural network architecture. You can use convolution networks, vision transformers, etc. Try with different architectures, different model sizes, and other hyper parameters such as learning rate and batch size to find the best performance. Other ideas could be to use augmentation thechniques to boost the performance, adding learning rate schedulers, and exploring other loss functions.
#
# Once you are happy with your model, continue with the rest of the notebook to save your checkpoint and also visualize some plans coming from the model. The last cell will provide a `submission_phase1.csv` which you can submit to the leaderboard to see your results on the testing set.

# %%
# save the model
torch.save(model.state_dict(), "phase1_model_augmented_GRU.pth")

# %%
val_batch_zero = next(iter(val_loader))
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
camera = val_batch_zero['camera'].to(device)
history = val_batch_zero['history'].to(device)
future = val_batch_zero['future'].to(device)

model.eval()
with torch.no_grad():
    pred_future = model(camera, history)

camera = camera.cpu().numpy()
history = history.cpu().numpy()
future = future.cpu().numpy()
pred_future = pred_future.cpu().numpy()
k=4
selected_indices = random.choices(np.arange(len(camera)), k=k)
# plot the camera view of current step for the k examples
fig, axis = plt.subplots(1, k, figsize=(4*k, 4))
for i, idx in enumerate(selected_indices):
    axis[i].imshow(camera[idx].transpose(1, 2, 0)/255)
    axis[i].axis("off")
plt.show()

# plot the past and future trajectory of the vehicle
fig, axis = plt.subplots(1, k, figsize=(4*k, 4))
for i, idx in enumerate(selected_indices):
    axis[i].plot(history[idx, :, 0], history[idx, :, 1], "o-", color="gold", label="Past")
    axis[i].plot(future[idx, :, 0], future[idx, :, 1], "o-", color="green", label="Future")
    axis[i].plot(pred_future[idx, :, 0], pred_future[idx, :, 1], "o-", color="red", label="Predicted")
    axis[i].legend()
    axis[i].axis("equal")
plt.show()

# %% [markdown]
# Now we run our model on the test set once, to get the plan of our model and save it for submission. Notice that the ground truth plans are removed for the test set, so you can not calculate the ADE metric on the test set yourself, and need to submit it to the leader board. By running the last cell, you'll be able to see a csv file called `submission_phase1.csv` by clicking on the folder icon on the left. Download it and submit it to the leaderboard to get your score.

# %%
with open(f"test_public/0.pkl", "rb") as f:
    data = pickle.load(f)
print(data.keys())
# Note the absence of sdc_future_feature
# Out:
# dict_keys(['camera', 'depth', 'driving_command', 'sdc_history_feature', 'semantic_label'])

# %%
import pandas as pd
test_data_dir = "test_public"
test_files = [os.path.join(test_data_dir, fn) for fn in sorted([f for f in os.listdir(test_data_dir) if f.endswith(".pkl")], key=lambda fn: int(os.path.splitext(fn)[0]))]

test_dataset = DrivingDataset(test_files, test=True)
test_loader = DataLoader(test_dataset, batch_size=250, num_workers=2)
model.eval()
all_plans = []
with torch.no_grad():
    for batch in test_loader:
        camera = batch['camera'].to(device)
        history = batch['history'].to(device)

        pred_future = model(camera, history)
        all_plans.append(pred_future.cpu().numpy()[..., :2])
all_plans = np.concatenate(all_plans, axis=0)

# Now save the plans as a csv file
pred_xy = all_plans[..., :2]  # shape: (total_samples, T, 2)

# Flatten to (total_samples, T*2)
total_samples, T, D = pred_xy.shape
pred_xy_flat = pred_xy.reshape(total_samples, T * D)

# Build a DataFrame with an ID column
ids = np.arange(total_samples)
df_xy = pd.DataFrame(pred_xy_flat)
df_xy.insert(0, "id", ids)

# Column names: id, x_1, y_1, x_2, y_2, ..., x_T, y_T
new_col_names = ["id"]
for t in range(1, T + 1):
    new_col_names.append(f"x_{t}")
    new_col_names.append(f"y_{t}")
df_xy.columns = new_col_names

# Save to CSV
df_xy.to_csv("submission_phase1.csv", index=False)

print(f"Shape of df_xy: {df_xy.shape}")
# Out:
# Shape of df_xy: (1000, 121)
